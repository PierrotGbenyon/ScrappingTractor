# %% [markdown]
# ![Image2.png](data:image/png;base64,...)
# ---------
# #**PROJET DE GROUPE -  MASTER 1 (MQME)**
# ---------
# # **Objectif principal :** Analyse de site de ventes Tracteurs : veille concurrentielle.
# ---------
# #**Année :** 2025-2026
#
# # **Participants :** Gwladys - Amadou_Garanke - Essossinam - Pierre Akouete - Pacifique - Perrin
# ----------------------------------------------------------------------------

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
